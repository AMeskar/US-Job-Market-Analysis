# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

#pd.set_option('display.max_rows', None)
#pd.set_option('display.max_columns', None)
#pd.set_option('display.width', None)
#pd.set_option('display.max_colwidth', None)

import sys
sys.path.append('/Users/meskara/Desktop/Github/Job_Market')

from src.Components.Data_Ingest import ListtoFDataFrame
from src.Components.Data_Transformation import DataFrame

# %%
folder_path = '/Users/meskara/Desktop/Github/Job_Market/src/Notebook/Data'

df = ListtoFDataFrame.DataIngestFunction(folder_path= folder_path)

# %%
df
# Out:
#           job_id                                              title  \
# 0     2803917600                      Entry Level Big Data Engineer
# 1     2785048853                           Junior Big Data Engineer
# 2     2819565442                                  Big Data Engineer
# 3     2818898895                    Big Data Engineer - Telecommute
# 4     2789623674                                  Big Data Engineer
# ...          ...                                                ...
# 5501  2799429762                                     Data Scientist
# 5502  2807137983                  Data Scientist, Product Analytics
# 5503  2794649106  Operations Research Data Scientist (Staff-Leve...
# 5504  2800194595                  Applied Machine Learning Engineer
# 5505  2807145771                                     Data Scientist
#
#                      comapany        date       location                place  \
# 0                     Comcast  2021-10-28  United States     West Chester, PA
# 1                        Citi  2021-10-10  United States            Tampa, FL
# 2                  Braintrust  2021-12-02  United States  Marina District, CA
# 3                       Optum  2021-12-03  United States         Columbia, MD
# 4                        Zoom  2021-12-03  United States         New York, NY
# ...                       ...         ...            ...                  ...
# 5501                     Meta  2021-11-19  United States         New York, NY
# 5502                     Meta  2021-11-20  United States           Austin, TX
# 5503      Walmart Global Tech  2021-11-16  United States           Dallas, TX
# 5504                 Coinbase  2021-11-19  United States       Washington, DC
# 5505  TechDigital Corporation  2021-11-20  United States     Bridgewater, NJ
#
#                                            job_function employment_type  \
# 0                Engineering and Information Technology       Full-time
# 1                Engineering and Information Technology       Full-time
# 2                Engineering and Information Technology       Full-time
# 3                Engineering and Information Technology       Full-time
# 4                Engineering and Information Technology       Full-time
# ...                                                 ...             ...
# 5501             Engineering and Information Technology       Full-time
# 5502             Engineering and Information Technology       Full-time
# 5503  Engineering, Information Technology, and Suppl...       Full-time
# 5504             Engineering and Information Technology       Full-time
# 5505                             Information Technology        Contract
#
#                                              industries  \
# 0     IT Services and IT Consulting, Internet Publis...
# 1     Banking, Financial Services, and Investment Ba...
# 2     Online Media, Publishing, and Internet Publishing
# 3     IT Services and IT Consulting, Wellness and Fi...
# 4     IT Services and IT Consulting, Computer Softwa...
# ...                                                 ...
# 5501                                Internet Publishing
# 5502                                Internet Publishing
# 5503  Transportation, Logistics and Storage, Compute...
# 5504  IT Services and IT Consulting, Computer Softwa...
# 5505                      IT Services and IT Consulting
#
#                                             description
# 0     Comcast brings together the best in media and ...
# 1     Job Id: 21360388\n\nThe Applications Developme...
# 2     JOB TYPE: Freelance, Contract Position - No ag...
# 3     Combine two of the fastest-growing fields on t...
# 4     We’re looking for a Big Data Engineer who can ...
# ...                                                 ...
# 5501  Facebook's mission is to give people the power...
# 5502  Facebook's mission is to give people the power...
# 5503  The Merchant Data Science team researches and ...
# 5504  Coinbase has built the world's leading complia...
# 5505  Job Title : Data Scientist - SO for CWR\n\nQua...
#
# [5506 rows x 10 columns]

# %%
df_new = DataFrame.Ingest(df)

# %%
df_new
# Out:
#      job_id                                              title  \
# 0       NaN                      entry level big data engineer
# 1       NaN                           junior big data engineer
# 2       NaN                                  big data engineer
# 3       NaN                    big data engineer - telecommute
# 4       NaN                                  big data engineer
# ...     ...                                                ...
# 5499    NaN                                     data scientist
# 5500    NaN  data scientist with python for $ backed ai sta...
# 5501    NaN                                     data scientist
# 5503    NaN  operations research data scientist (staff-leve...
# 5505    NaN                                     data scientist
#
#                      comapany        date       location                place  \
# 0                     comcast  2021-10-28  united states     west chester, pa
# 1                        citi  2021-10-10  united states            tampa, fl
# 2                  braintrust  2021-12-02  united states  marina district, ca
# 3                       optum  2021-12-03  united states         columbia, md
# 4                        zoom  2021-12-03  united states         new york, ny
# ...                       ...         ...            ...                  ...
# 5499                    sysco  2021-11-09  united states          houston, tx
# 5500                  optello  2021-11-18  united states           boston, ma
# 5501                     meta  2021-11-19  united states         new york, ny
# 5503      walmart global tech  2021-11-16  united states           dallas, tx
# 5505  techdigital corporation  2021-11-20  united states     bridgewater, nj
#
#                                            job_function employment_type  \
# 0                engineering and information technology       full-time
# 1                engineering and information technology       full-time
# 2                engineering and information technology       full-time
# 3                engineering and information technology       full-time
# 4                engineering and information technology       full-time
# ...                                                 ...             ...
# 5499             engineering and information technology       full-time
# 5500                             information technology       full-time
# 5501             engineering and information technology       full-time
# 5503  engineering, information technology, and suppl...       full-time
# 5505                             information technology        contract
#
#                                              industries  \
# 0     it services and it consulting, internet publis...
# 1     banking, financial services, and investment ba...
# 2     online media, publishing, and internet publishing
# 3     it services and it consulting, wellness and fi...
# 4     it services and it consulting, computer softwa...
# ...                                                 ...
# 5499  construction, food and beverage services, and ...
# 5500  it services and it consulting, computer softwa...
# 5501                                internet publishing
# 5503  transportation, logistics and storage, compute...
# 5505                      it services and it consulting
#
#                                             description
# 0     comcast brings together the best in media and ...
# 1     job id: 21360388\n\nthe applications developme...
# 2     job type: freelance, contract position - no ag...
# 3     combine two of the fastest-growing fields on t...
# 4     we’re looking for a big data engineer who can ...
# ...                                                 ...
# 5499  company\n\nus6469 sysco payroll, division of s...
# 5500  if you are a data scientist who is looking to ...
# 5501  facebook's mission is to give people the power...
# 5503  the merchant data science team researches and ...
# 5505  job title : data scientist - so for cwr\n\nqua...
#
# [4690 rows x 10 columns]
