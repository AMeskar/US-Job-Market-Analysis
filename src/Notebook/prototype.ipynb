# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

#pd.set_option('display.max_rows', None)
#pd.set_option('display.max_columns', None)
#pd.set_option('display.width', None)
#pd.set_option('display.max_colwidth', None)

import os

# %%
list_files = os.listdir('/Users/meskara/Desktop/Github/Job_Market/src/Notebook/Data')

# %%
list_files
# Out:
# ['CSVbigdataengineer.csv',
#  'CSVML.csv',
#  'CSVstatisticalAnalyst.csv',
#  'CSVresearcher.csv',
#  'CSVdataAnalyst.csv',
#  'CSVFILE.csv']

# %%
data_analyst = pd.read_csv('/Users/meskara/Desktop/Github/Job_Market/src/Notebook/Data/CSVdataAnalyst.csv', encoding='cp1252')
data_scientist = pd.read_csv('/Users/meskara/Desktop/Github/Job_Market/src/Notebook/Data/CSVFILE.csv', encoding='cp1252')
data_ml = pd.read_csv('/Users/meskara/Desktop/Github/Job_Market/src/Notebook/Data/CSVML.csv', encoding='cp1252')
data_statisticalAnalyst = pd.read_csv('/Users/meskara/Desktop/Github/Job_Market/src/Notebook/Data/CSVstatisticalAnalyst.csv', encoding='cp1252')
data_researcher = pd.read_csv('/Users/meskara/Desktop/Github/Job_Market/src/Notebook/Data/CSVresearcher.csv', encoding='cp1252')
data_bigdata = pd.read_csv('/Users/meskara/Desktop/Github/Job_Market/src/Notebook/Data/CSVbigdataengineer.csv', encoding='cp1252')

# %%
df = pd.concat([data_analyst, data_scientist, data_ml, data_researcher, data_bigdata, data_statisticalAnalyst])
df_new = df.drop_duplicates().sort_index()

# %%
df_new
# Out:
#          job_id                                              title  \
# 0    2801690476                                       Data Analyst
# 0    2803917600                      Entry Level Big Data Engineer
# 0    2799459539                                Researcher, The Row
# 0    2807317112                          Machine Learning Engineer
# 0    2800158106                                     Data Scientist
# ..          ...                                                ...
# 963  2800910074  Senior Data Scientist - Machine Learning [Remote]
# 964  2800907510  Senior Data Scientist - Machine Learning [Remote]
# 965  2800907639  Senior Data Scientist - Machine Learning [Remote]
# 966  2807221058  Data Scientist Intern – IBM Garage - Summit Su...
# 967  2800909306  Senior Data Scientist - Machine Learning [Remote]
#
#            comapany        date       location                   place  \
# 0    Webmasters4SEO  2021-11-20  United States           United States
# 0           Comcast  2021-10-28  United States        West Chester, PA
# 0               CNN  2021-11-19  United States             Atlanta, GA
# 0          Domino's  2021-11-21  United States           Ann Arbor, MI
# 0    The Home Depot  2021-11-19  United States             Atlanta, GA
# ..              ...         ...            ...                     ...
# 963          HiRoad  2021-11-19  United States              Conway, SC
# 964          HiRoad  2021-11-19  United States  North Myrtle Beach, SC
# 965          HiRoad  2021-11-19  United States         New Orleans, LA
# 966             IBM  2021-11-20  United States            New York, NY
# 967          HiRoad  2021-11-19  United States         Kansas City, KS
#
#                                       job_function employment_type  \
# 0                                              NaN       Full-time
# 0           Engineering and Information Technology       Full-time
# 0    Research, Analyst, and Information Technology       Full-time
# 0                                              NaN       Full-time
# 0                                              NaN       Full-time
# ..                                             ...             ...
# 963         Engineering and Information Technology       Full-time
# 964         Engineering and Information Technology       Full-time
# 965         Engineering and Information Technology       Full-time
# 966                                          Sales       Full-time
# 967         Engineering and Information Technology       Full-time
#
#                                             industries  \
# 0                                                  NaN
# 0    IT Services and IT Consulting, Internet Publis...
# 0          Broadcast Media Production and Distribution
# 0                                                  NaN
# 0                                                  NaN
# ..                                                 ...
# 963                                          Insurance
# 964                                          Insurance
# 965                                          Insurance
# 966                    Computer Hardware Manufacturing
# 967                                          Insurance
#
#                                            description
# 0    What you’ll do\nThe business analyst would wor...
# 0    Comcast brings together the best in media and ...
# 0    Company Overview\n\nWarnerMedia is a powerful ...
# 0    Help Domino's Data Science Center of Excellenc...
# 0    Data scientist, Space Optimization link:\n\nht...
# ..                                                 ...
# 963  Our Mission\n\nWe make good things happen by r...
# 964  Our Mission\n\nWe make good things happen by r...
# 965  Our Mission\n\nWe make good things happen by r...
# 966  Introduction\n\nDo you want to use your new te...
# 967  Our Mission\n\nWe make good things happen by r...
#
# [4690 rows x 10 columns]

# %%
for col in df.columns:
    
   df_new[col] = df_new[col].str.lower()

# %%
skills = ['python', 'r', 'numpy', 'pandas', 'impala', 'unix', 'pig', 'hbase',
          'scikit-learn', 'java', 'seaborn', 'pyspark', 'kafka', 'postgres',
          'c', 'c++', 'hadoop', 'spark', 'sql', 'spreadsheets', 'matlab',
          'nosql', 'mongodb', 'scala', 'sas', 'html', 'css', 'javascript',
          'powerpoint', 'aws', 'azure', 'gcp', 'tableau', 'cassandra', 'excel',
          'mysql', 'linux', 'hive', 'perl', 'tensorflow', 'pytorch', 'keras']

def executionSkill(x):

    skill_array = []

    for skill in skills:

        if skill.lower() in x.lower():

            skill_array.append(skill)
            
    if skill_array==[]: skill_array.append('no requirement specified')
    
    return skill_array

df_new['skills'] = df_new['description'].apply(lambda x: executionSkill(x))

education = ['bachelor', 'master', 'ms', 'm.s', 'bs', 'b.s', 'phd', 'ph.d', 'doctorate', 'postgraduate']

def executionEducation(x):

    edu_array = []

    for edu in education:

        if edu.lower() in x.lower():

            edu_array.append(edu)
            
    if edu_array==[]: edu_array.append('no requirement specified')
    
    return edu_array

df_new['education'] = df_new['description'].apply(lambda x: executionEducation(x))

concepts = [
    'statistics', 'data visualization', 'cloud computing', 'distributed system',
    'ml', 'machine learning', 'ai', 'artificial intelligence',
    'communication skills', 'mathematics', 'maths', 'critical thinking',
    'data warehousing', 'problem solving', 'research', 'project management',
    'bi', 'business intelligence', 'etl', 'preprocessing', 'feature engineering',
    'data manipulation', 'probability', 'neural network', 'computer vision',
    'deep learning', 'data mining', 'big data'
]

def executionConcept(x):

    concept_array = []

    for con in concepts:

        if con.lower() in x.lower():

            concept_array.append(con)
            
    if concept_array==[]: concept_array.append('no requirement specified')
    
    return concept_array

df_new['concepts'] = df_new['description'].apply(lambda x: executionConcept(x))

majors = [
    'computer science', 'computer engineering', 'mathematics', 'maths', 'statistics',
    'data science', 'datascience', 'engineering', 'machine learning',
    'computer vision', 'electrical engineering', 'ee', 'applied math', 'finance'
]

def executionMajors(x):

    Major_array = []

    for maj in majors:

        if maj.lower() in x.lower():

            Major_array.append(maj)
            
    if Major_array==[]: Major_array.append('no requirement specified')
    
    return Major_array

df_new['majors'] = df_new['description'].apply(lambda x: executionMajors(x))

# %%
df_new.drop('description', axis= 1)
# Out:
#          job_id                                              title  \
# 0    2801690476                                       data analyst
# 0           NaN                      entry level big data engineer
# 0           NaN                                researcher, the row
# 0           NaN                          machine learning engineer
# 0           NaN                                     data scientist
# ..          ...                                                ...
# 963         NaN  senior data scientist - machine learning [remote]
# 964         NaN  senior data scientist - machine learning [remote]
# 965         NaN  senior data scientist - machine learning [remote]
# 966         NaN  data scientist intern – ibm garage - summit su...
# 967         NaN  senior data scientist - machine learning [remote]
#
#            comapany        date       location                   place  \
# 0    webmasters4seo  2021-11-20  united states           united states
# 0           comcast  2021-10-28  united states        west chester, pa
# 0               cnn  2021-11-19  united states             atlanta, ga
# 0          domino's  2021-11-21  united states           ann arbor, mi
# 0    the home depot  2021-11-19  united states             atlanta, ga
# ..              ...         ...            ...                     ...
# 963          hiroad  2021-11-19  united states              conway, sc
# 964          hiroad  2021-11-19  united states  north myrtle beach, sc
# 965          hiroad  2021-11-19  united states         new orleans, la
# 966             ibm  2021-11-20  united states            new york, ny
# 967          hiroad  2021-11-19  united states         kansas city, ks
#
#                                       job_function employment_type  \
# 0                                              NaN       full-time
# 0           engineering and information technology       full-time
# 0    research, analyst, and information technology       full-time
# 0                                              NaN       full-time
# 0                                              NaN       full-time
# ..                                             ...             ...
# 963         engineering and information technology       full-time
# 964         engineering and information technology       full-time
# 965         engineering and information technology       full-time
# 966                                          sales       full-time
# 967         engineering and information technology       full-time
#
#                                             industries  \
# 0                                                  NaN
# 0    it services and it consulting, internet publis...
# 0          broadcast media production and distribution
# 0                                                  NaN
# 0                                                  NaN
# ..                                                 ...
# 963                                          insurance
# 964                                          insurance
# 965                                          insurance
# 966                    computer hardware manufacturing
# 967                                          insurance
#
#                                                 skills  \
# 0                                        [r, c, excel]
# 0    [python, r, unix, c, hadoop, spark, sql, scala...
# 0                                               [r, c]
# 0                                        [r, c, excel]
# 0                                               [r, c]
# ..                                                 ...
# 963  [python, r, numpy, pandas, scikit-learn, seabo...
# 964  [python, r, numpy, pandas, scikit-learn, seabo...
# 965  [python, r, numpy, pandas, scikit-learn, seabo...
# 966  [python, r, pandas, scikit-learn, c, spark, li...
# 967  [python, r, numpy, pandas, scikit-learn, seabo...
#
#                                               concepts  \
# 0                      [ai, bi, business intelligence]
# 0              [cloud computing, ml, ai, research, bi]
# 0                                   [ai, research, bi]
# 0                                   [machine learning]
# 0                                                 [ml]
# ..                                                 ...
# 963               [machine learning, ai, research, bi]
# 964               [machine learning, ai, research, bi]
# 965               [machine learning, ai, research, bi]
# 966  [statistics, data visualization, ml, machine l...
# 967               [machine learning, ai, research, bi]
#
#                       education  \
# 0                          [ms]
# 0                [bachelor, ms]
# 0                          [bs]
# 0    [no requirement specified]
# 0    [no requirement specified]
# ..                          ...
# 963                    [ms, bs]
# 964                    [ms, bs]
# 965                    [ms, bs]
# 966      [bachelor, master, ms]
# 967                    [ms, bs]
#
#                                                 majors
# 0                                                 [ee]
# 0                                    [engineering, ee]
# 0                                                 [ee]
# 0                     [data science, machine learning]
# 0                                                 [ee]
# ..                                                 ...
# 963  [data science, engineering, machine learning, ee]
# 964  [data science, engineering, machine learning, ee]
# 965  [data science, engineering, machine learning, ee]
# 966  [computer science, statistics, data science, e...
# 967  [data science, engineering, machine learning, ee]
#
# [4690 rows x 13 columns]
